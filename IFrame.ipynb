# %%
from IPython.display import display, IFrame, HTML, Image
url = "https://www.openstreetmap.org/export/embed.html?bbox=-76.27412796020509%2C42.977902207217845%2C-76.04753494262697%2C43.09258461074793&amp;layer=mapnik"
frame = IFrame(src  = url,
              width=300, height=200)
display(HTML("<h1>Syracuse</h1>"))
display(Image("https://crosspointecg.com/wp-content/uploads/2019/01/partly-cloudy-300x260.jpg", width=50))
display(frame)
# Out:
# <h1>Syracuse</h1>
#         <iframe
#             width="300"
#             height="200"
#             src="https://www.openstreetmap.org/export/embed.html?bbox=-76.27412796020509%2C42.977902207217845%2C-76.04753494262697%2C43.09258461074793&amp;layer=mapnik"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
