# %%
import pyodbc
import pandas as pd

server = 'tcp:ist-cs-dw1.ad.syr.edu' 
database = 'jade' 
username = 'jadeuser' 
password = 'SU2orange!' 
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()

# %%
cursor.execute("SELECT @@version;") 
row = cursor.fetchone() 
while row: 
    print (row[0])
    row = cursor.fetchone()
# Out:
# Microsoft SQL Server 2014 (SP3-CU4) (KB4500181) - 12.0.6329.1 (X64)
# 	Jul 20 2019 21:42:29
# 	Copyright (c) Microsoft Corporation
# 	Enterprise Edition (64-bit) on Windows NT 6.3 <X64> (Build 9600: ) (Hypervisor)

# %%
pd.read_sql("SELECT * FROM store", cnxn)
# Out:
#      store_number  store_name           store_type         address1  \
# 0            1010       Paris          Mini Outlet  Street Name 581
# 1            1011        Lyon          Full Outlet  Street Name 288
# 2            1012    Toulouse          Full Outlet   Street Name 28
# 3            1013        Nice          Full Outlet  Street Name 562
# 4            1014  Strasbourg  Distribution Centre  Street Name 798
# ..            ...         ...                  ...              ...
# 97           3412       Essen          Full Outlet  Street Name 264
# 98           3413   Stuttgart          Full Outlet  Street Name 959
# 99           3414    Dortmund          Full Outlet  Street Name 410
# 100          3415  Dusseldorf          Full Outlet  Street Name 717
# 101          3416      Bremen          Full Outlet  Street Name 647
#
#          address2      address3 address4        city state zipcode country  \
# 0    Locality 421  District 379     None       Paris   N/A  V2774W      FR
# 1    Locality 348  District 288     None        Lyon   N/A   W779A      FR
# 2    Locality 503   District 99     None    Toulouse   N/A  R8207Y      FR
# 3    Locality 422  District 749     None        Nice   N/A  N7751M      FR
# 4    Locality 575  District 566     None  Strasbourg   N/A  N5998M      FR
# ..            ...           ...      ...         ...   ...     ...     ...
# 97   Locality 307  District 483     None       Essen   N/A  Q1946Q      DE
# 98   Locality 281  District 649     None   Stuttgart   N/A  S8069S      DE
# 99   Locality 635  District 962     None    Dortmund   N/A    Q718      DE
# 100  Locality 953  District 634     None  Dusseldorf   N/A    F259      DE
# 101   Locality 13  District 173     None      Bremen   N/A    J138      DE
#
#     phone_number                                        web_site   region  \
# 0      57-954840       http://www.amadeusentertainment.com/Paris   France
# 1      94-250828        http://www.amadeusentertainment.com/Lyon   France
# 2      71-639025    http://www.amadeusentertainment.com/Toulouse   France
# 3       27-75398        http://www.amadeusentertainment.com/Nice   France
# 4      78-137128  http://www.amadeusentertainment.com/Strasbourg   France
# ..           ...                                             ...      ...
# 97      6-233332       http://www.amadeusentertainment.com/Essen  Germany
# 98     87-676131   http://www.amadeusentertainment.com/Stuttgart  Germany
# 99     24-389826    http://www.amadeusentertainment.com/Dortmund  Germany
# 100    67-597624  http://www.amadeusentertainment.com/Dusseldorf  Germany
# 101    24-459756      http://www.amadeusentertainment.com/Bremen  Germany
#
#     division    created last_updated
# 0       EMEA 2007-03-15   2007-03-31
# 1       EMEA 2007-03-15   2007-04-29
# 2       EMEA 2007-03-15   2007-04-14
# 3       EMEA 2007-03-15   2007-04-15
# 4       EMEA 2007-03-15   2007-05-23
# ..       ...        ...          ...
# 97      EMEA 2007-03-15   2007-06-23
# 98      EMEA 2007-03-15   2007-03-31
# 99      EMEA 2007-03-15   2007-03-25
# 100     EMEA 2007-03-15   2007-04-26
# 101     EMEA 2007-03-15   2007-03-17
#
# [102 rows x 17 columns]
